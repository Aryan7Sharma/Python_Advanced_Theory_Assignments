# %% [markdown]
# # Assingment02_sol

# %% [markdown]
#     Q1. What is the relationship between classes and modules?
#
#     sol--> Classes may generate instances (objects) and Modules may be mixed in to classes and other modules, we need to import the particular module before use the classes and methods of that module.for example if we want to use the pre-built sqrt()function then we need to import the math module First then we are able to use that function().
#
#
#
#     Q2. How do you make instances and classes?
#
#     sol--> To create instances of a class, you call the class using class name and pass in whatever arguments its __init__ method accepts.
#
#     class Temp:
#         def __init__(self):
#             pass
#         pass
#
#     obj=Temp()
#
#
#
#     Q3. Where and how should be class attributes created?
#
#     sol--> Class attributes are attributes which are owned by the class itself. They will be shared by all the instances of the class So the Class attributes are the variables defined directly in the class.
#
#     class Sum:
#         a=1
#         b=2
#         def func1(self):
#             return Sum.a+Sum.b
#
#     obj=Sum()
#     obj.func1()
#
#
#
#     Q4. Where and how are instance attributes created?
#
#     sol--> Instance attributes are attributes or properties attached to an instance of a class. Instance attributes are defined in the constructor.
#
#
#            class Sum:
#                def __init__(self, a, b):
#                self.a=a
#                self.b =b
#
#            obj=Sum(1,2)
#
#
#
#     Q5. What does the term "self" in a Python class mean?
#
#     sol--> The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class. and self is not a  keyword we can use any name for that.
#
#
#
#     Q6. How does a Python class handle operator overloading?
#
#     sol--> The operator overloading in Python means provide extended meaning beyond their predefined operational meaning. Such as, we use the "+" operator for adding two integers as well as joining two strings or merging two lists. We can achieve this as the "+" operator is overloaded by the "int" class and "str" class.
#
#     def temp(a,b):
#         return a+b:
#
#      print(temp(5,6))                  --> 11
#      print(temp("hi","iNeuron"))       --> hiiNeuron
#      print(temp([1,2,3],[4]))          --> [1,2,3,4]
#
#
#
#     Q7. When do you consider allowing operator overloading of your classes?
#
#     sol-->
#               def temp(a,b):
#                   return a+b:
#
#               print(temp(5,6))                  --> 11
#               print(temp("hi","iNeuron"))       --> hiiNeuron
#               print(temp([1,2,3],[4]))          --> [1,2,3,4]
#
#
#
#     Q8. What is the most popular form of operator overloading?
#
#     sol--> A very popular and convenient example is the Addition (+) operator. which i already give in the sol6 and sol7.
